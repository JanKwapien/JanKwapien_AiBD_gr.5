# %%
import pandas as pd
import numpy as np
import time
from datetime import datetime, date, time, timedelta

# %%
data = pd.read_csv("../Analysis Data/analysisData_1.csv")
data
# Out:
#       Unnamed: 0  year           artist                     track  time  \
# 0              0  2000  Destiny's Child  Independent Women Part I  3:38
# 1              1  2000  Destiny's Child  Independent Women Part I  3:38
# 2              2  2000  Destiny's Child  Independent Women Part I  3:38
# 3              3  2000  Destiny's Child  Independent Women Part I  3:38
# 4              4  2000  Destiny's Child  Independent Women Part I  3:38
# ...          ...   ...              ...                       ...   ...
# 5302        5302  2000    Zombie Nation             Kernkraft 400  3:30
# 5303        5303  2000    Zombie Nation             Kernkraft 400  3:30
# 5304        5304  2000   Eastsidaz, The                  Got Beef  3:58
# 5305        5305  2000   Eastsidaz, The                  Got Beef  3:58
# 5306        5306  2000           Fragma            Toca's Miracle  3:22
#
#             date  week  place
# 0     2000-09-23     1     78
# 1     2000-09-30     2     63
# ...

# %%
weeks_in_charts = {}


for d,r in data.iterrows():
    total_weeks = r["week"]  
    weeks_in_charts[r["track"]] = total_weeks
    
lines = ["#Analisys of processed data","","Every song will have it's total time in top charts listed",""]
for k, v in weeks_in_charts.items():
    lines.append("\" {} \" was in charts for: {} weeks\n".format(k,v))
    
with open("../Docs/Analisys.md",'w') as file:
    for line in lines:
        file.write(line)
